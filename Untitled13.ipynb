# %%
from transformers import GPT2LMHeadModel, GPT2Tokenizer

tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
model = GPT2LMHeadModel.from_pretrained("gpt2")

prompt = input("Enter your story idea: ")
inputs = tokenizer(prompt, return_tensors="pt")

output = model.generate(
    inputs["input_ids"],
    max_length=200,
    temperature=0.9,
    top_p=0.95,
    do_sample=True,
    pad_token_id=tokenizer.eos_token_id
)

story = tokenizer.decode(output[0], skip_special_tokens=True)
print('\n' + story)
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Enter your story idea: a lion lost in the city
#
# a lion lost in the city's wild, but a few thousand years ago, a group of people formed the Narnia tribe, claiming the city was theirs. But the people of the Narnia, who were called Narnian, were much stronger than the Narnian people. So they found it, made it into a city, and founded a new town, Narnia.
#
# (See the following timeline of Narnia's history.)
#
# Then, in the late nineteenth century, the Narnian people made their homeland, Narnia. Narnia lived in a lush land, and it's known today for having a very good weather, as well as a good people. And when the Narnians conquered Narnia, Narnian people began to form a military, and in about a century, they started to gather here.
#
# So, Narnia was founded, and the Narnians built a kingdom. It's known
